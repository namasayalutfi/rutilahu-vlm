# %%
from huggingface_hub import HfApi

api = HfApi()

# %%
repo_id = "lfixfey/mkn_vlm_dataset"

api.upload_file(
    path_or_fileobj="data/sft/test.jsonl", # Path lokal ke file yang ingin diupload
    path_in_repo="data/sft/test.jsonl", # Ini akan otomatis membuat folder sft jika belum ada
    repo_id=repo_id,
    repo_type="dataset"
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/datasets/lfixfey/mkn_vlm_dataset/commit/bc2214e5be76a12c0cd44b6ca137c6d02ef1d1a1', commit_message='Upload data/sft/test.jsonl with huggingface_hub', commit_description='', oid='bc2214e5be76a12c0cd44b6ca137c6d02ef1d1a1', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/lfixfey/mkn_vlm_dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='lfixfey/mkn_vlm_dataset'), pr_revision=None, pr_num=None)
